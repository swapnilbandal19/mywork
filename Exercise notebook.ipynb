# %% [markdown]
# #  "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Swapnil Bandal**

# %% [markdown]
# I am working for Industrial process development, desired to be a good data scienctist to explore data to find insights for process optimization

# %% [markdown]
# _I am instrested in data science becasuse i love to explore data and data co relations. Use of Power of data in problem solving_

# %% [markdown]
# ### I am a beginner for code writing in Python So i am writting easy code

# %%
a=1
b=5
c=a+b

print(c)
# Out:
# 6

# %% [markdown]
# ---

# %% [markdown]
# 1. Sunday
# 2. Monday
# 4. Tuesday
# 4. Wednesday
# 3. Thursday
# 3. Friday
# 2. Saturday

# %% [markdown]
# * one
# * two

# %% [markdown]
# |sr|description|remark|
# |---|---|---|
# |1|start up|no issue|
# |2|Shut down|smooth|
